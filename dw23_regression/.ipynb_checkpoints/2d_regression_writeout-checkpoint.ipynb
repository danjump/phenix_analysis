# %%
# %matplotlib inline
import pylab as pb
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
import GPy as GPy
pb.ion()

# %% [markdown]
# #------------------------------------
# # Read/Prepare input data
# #------------------------------------

# %%
# read from file
# file contains a list of entries describing bins from
# a 2d dw23 vs wness yield histogram
data = pd.read_csv('dw23_vs_wness_list.txt',
                sep=' ',
                index_col=['index'],
                usecols=['index','arm','charge','wness_bin_center',
                         'dw23_bin_center','entries'])

# select the arm/charge/wness region for the data points
def get_data_array(data,which,arm,charge,wthr):
    ''' simple function to filter events from dataframe and get array
    which=0 -> coordinates 2 column array
    which=1 -> values 1 column array
    which=2 -> coordinates and values 3 column array
    '''
    
    if which==1:
        cols = ['entries']
    elif which==0:
        cols = ['dw23_bin_center','wness_bin_center']
    elif which==2:
        cols = ['dw23_bin_center','wness_bin_center','entries']
        
    array = data[data['arm']==arm][data['charge']==charge][data['wness_bin_center']<wthr]\
            [data['wness_bin_center']>.1].as_matrix(cols)
        
    return array

#zero-initialize variables as 2,2,3 arrays for arm,charge,threshold
coordinates = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
values = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
uncert = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
full_array = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
scaled_values = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
scaled_uncert = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]

def normalize_vs_wness(array,uncert):
    sum_dict = dict()
    for dw23 in np.arange(-.29,.31,.02):
        dw23 = np.around(dw23,2)
        summed_vs_wness = np.sum(array[array[:,0]==dw23][:,2],axis=0)
        sum_dict[dw23] = summed_vs_wness
        
    for i in range(0,len(array)):
        array[i,2] /= sum_dict[array[i,0]]
        uncert[i] /= sum_dict[array[i,0]]
    return array[:,2].reshape(len(array),1), uncert

for arm in range(2):
    for charge in range(2):
        for thr in range(3):
            #assign un-modified data content
            coordinates[arm][charge][thr] = get_data_array(data,0,arm,charge,.7+thr/10.)
            values[arm][charge][thr] = get_data_array(data,1,arm,charge,.7+thr/10.)
            uncert[arm][charge][thr] = np.sqrt(values[arm][charge][thr])
            
            full_array[arm][charge][thr] = get_data_array(data,2,arm,charge,.7+thr/10.)
            scaled_values[arm][charge][thr],scaled_uncert[arm][charge][thr] = normalize_vs_wness(full_array[arm][charge][thr],uncert[arm][charge][thr])

# %%
# take the log of all values to make them compatible with the GPR fit
# note: add 2 to transform 
log_values = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
log_uncert = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
for arm in range(2):
    for charge in range(2):
        for thr in range(3):
            log_values[arm][charge][thr] = np.log(values[arm][charge][thr]+2)
            log_values[arm][charge][thr][np.invert(np.isfinite(values[arm][charge][thr]))]=0
            log_uncert[arm][charge][thr] = np.log(uncert[arm][charge][thr])
            log_uncert[arm][charge][thr][np.invert(np.isfinite(uncert[arm][charge][thr]))]=0.

# %% [markdown]
# #-----------------------------------------
# # Do Gaussian Proccess Regression on Data
# #-----------------------------------------

# %%
coords = coordinates[0][0][0]
vals = scaled_values[0][0][0]
uncertainty = scaled_uncert[0][0][0]

print('Input Array Shapes:')
print('coordinates',type(coords),coords.shape)
print('values',type(vals),vals.shape)
print('uncert',type(uncertainty),uncertainty.shape)
# Out:
# Input Array Shapes:
# ('coordinates', <type 'numpy.ndarray'>, (900, 2))
# ('values', <type 'numpy.ndarray'>, (900, 1))
# ('uncert', <type 'numpy.ndarray'>, (900, 1))

# %%
coords = coordinates[0][0][2]
vals = values[0][0][2]
uncertainty = uncert[0][0][2]

print('Input Array Shapes:')
print('coordinates',type(coords),coords.shape)
print('values',type(vals),vals.shape)
print('uncert',type(uncertainty),uncertainty.shape)

#defien an rbf kernel for each dimension of the distribution
ker0 = GPy.kern.RBF(input_dim=1,variance=100,lengthscale=.05,active_dims=[0])
ker1 = GPy.kern.RBF(input_dim=1,variance=100,lengthscale=.05,active_dims=[1])
#define a fixed diagonal kernel of the know input variance of the data-points
kerfixed = GPy.kern.Fixed(2,GPy.util.linalg.tdot(uncertainty))
#construct final kernel
kernel = ker0 * ker1 + kerfixed

#create model
model = GPy.models.GPRegression(coords,vals,kernel)
#fix the noise parameter to essentially 0 since we
#are using known input variance:
model.Gaussian_noise.fix(1e-6)

model.optimize(max_f_eval = 1000)
print(model)

#user defined function to generate a 120x200 grid of points at which to obtain predictions
predict_points = get_dw23_wness_coords(1, 120.,-.3,.3, 200.,0.,1.)
print('Prediction points shape:'+str(predict_points.shape))
mean, varience = model.predict(predict_points)
# Out:
# Input Array Shapes:
# ('coordinates', <type 'numpy.ndarray'>, (1200, 2))
# ('values', <type 'numpy.ndarray'>, (1200, 1))
# ('uncert', <type 'numpy.ndarray'>, (1200, 1))
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
#
# Name                 : GP regression
# Log-likelihood       : -3977.70455704
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |       Value       |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |    10.0624849202  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.0173866088801  |     +ve      |         |
#   add.mul.rbf_2.variance     |    10.0624849177  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |  0.0178426009088  |     +ve      |         |
#   add.fixed.variance         |    64.6807037111  |     +ve      |         |
#   Gaussian_noise.variance    |            1e-06  |    fixed     |         |
# Prediction points shape:(24000, 2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-e7691028d01b> in <module>()
#      28 predict_points = get_dw23_wness_coords(1, 120.,-.3,.3, 200.,0.,1.)
#      29 print('Prediction points shape:'+str(predict_points.shape))
# ---> 30 mean, varience = model.predict(predict_points)
#
# /usr/local/lib/python2.7/dist-packages/GPy-0.6.1-py2.7.egg/GPy/core/gp.pyc in predict(self, Xnew, full_cov, Y_metadata, kern)
#     216         """
#     217         #predict the latent function values
# --> 218         mu, var = self._raw_predict(Xnew, full_cov=full_cov, kern=kern)
#     219         if self.normalizer is not None:
#     220             mu, var = self.normalizer.inverse_mean(mu), self.normalizer.inverse_variance(var)
#
# /usr/local/lib/python2.7/dist-packages/GPy-0.6.1-py2.7.egg/GPy/core/gp.pyc in _raw_predict(self, _Xnew, full_cov, kern)
#     180             kern = self.kern
#     181
# --> 182         Kx = kern.K(_Xnew, self.X).T
#     183         WiKx = np.dot(self.posterior.woodbury_inv, Kx)
#     184         mu = np.dot(Kx.T, self.posterior.woodbury_vector)
#
# /usr/local/lib/python2.7/dist-packages/GPy-0.6.1-py2.7.egg/GPy/kern/_src/kernel_slice_operations.pyc in wrap(self, X, X2, *a, **kw)
#      63     def wrap(self, X, X2 = None, *a, **kw):
#      64         with _Slice_wrap(self, X, X2) as s:
# ---> 65             ret = f(self, s.X, s.X2, *a, **kw)
#      66         return ret
#      67     return wrap
#
# /usr/local/lib/python2.7/dist-packages/GPy-0.6.1-py2.7.egg/GPy/util/caching.pyc in __call__(self, *args, **kwargs)
#     180         except KeyError:
#     181             cacher = caches[self.f] = Cacher(self.f, self.limit, self.ignore_args, self.force_kwargs)
# --> 182         return cacher(*args, **kwargs)
#     183
#     184 class Cache_this(object):
#
# /usr/local/lib/python2.7/dist-packages/GPy-0.6.1-py2.7.egg/GPy/util/caching.pyc in __call__(self, *args, **kw)
#     106             #print 'WARNING: '+self.operation.__name__ + ' not cacheable!'
#     107             #print [not (isinstance(b, Observable)) for b in inputs]
# --> 108             return self.operation(*args, **kw)
#     109         # 3&4: check whether this cache_id has been cached, then has it changed?
#     110         try:
#
# /usr/local/lib/python2.7/dist-packages/GPy-0.6.1-py2.7.egg/GPy/kern/_src/add.pyc in K(self, X, X2, which_parts)
#      36             # if only one part is given
#      37             which_parts = [which_parts]
# ---> 38         return reduce(np.add, (p.K(X, X2) for p in which_parts))
#      39
#      40     @Cache_this(limit=2, force_kwargs=['which_parts'])
#
# ValueError: operands could not be broadcast together with shapes (24000,1200) (1200,1200)

# %%
coords = coordinates[0][0][2]
vals = values[0][0][2]
uncertainty = uncert[0][0][2]

print('Input Array Shapes:')
print('coordinates',type(coords),coords.shape)
print('values',type(vals),vals.shape)
print('uncert',type(uncertainty),uncertainty.shape)

#defien an rbf kernel for each dimension of the distribution
ker0 = GPy.kern.RBF(input_dim=1,variance=100,lengthscale=.05,active_dims=[0])
ker1 = GPy.kern.RBF(input_dim=1,variance=100,lengthscale=.05,active_dims=[1])
#construct final kernel
kernel = ker0 * ker1

#create model
model = GPy.models.GPRegression(coords,vals,kernel)

model.optimize(max_f_eval = 1000)
print(model)

#user defined function to generate a 120x200 grid of points at which to obtain predictions
predict_points = get_dw23_wness_coords(1, 120.,-.3,.3, 200.,0.,1.)
print('Prediction points shape:'+str(predict_points.shape))
mean, varience = model.predict(predict_points)
# Out:
# Input Array Shapes:
# ('coordinates', <type 'numpy.ndarray'>, (1200, 2))
# ('values', <type 'numpy.ndarray'>, (1200, 1))
# ('uncert', <type 'numpy.ndarray'>, (1200, 1))
#
# Name                 : GP regression
# Log-likelihood       : -3117.71164156
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value       |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |    30.6140441633  |     +ve      |         |
#   mul.rbf_1.lengthscale    |  0.0502088242729  |     +ve      |         |
#   mul.rbf_2.variance       |    30.6140441608  |     +ve      |         |
#   mul.rbf_2.lengthscale    |   0.340895105215  |     +ve      |         |
#   Gaussian_noise.variance  |    7.78585671365  |     +ve      |         |
# Prediction points shape:(24000, 2)

# %%
kerdw23 = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
kerw = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
ker = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]

kerdw23uncert = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
kerwuncert = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
kerfix = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
keruncert = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]

m = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
m_uncert = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]

for arm in range(2):
    for charge in range(2):
        for thr in range(3):

            # create simple model:
            kerdw23[arm][charge][thr] = GPy.kern.RBF(input_dim=1,variance=100,lengthscale=.05,active_dims=[0])
            kerw[arm][charge][thr] = GPy.kern.RBF(input_dim=1,variance=100,lengthscale=.05,active_dims=[1])
            ker[arm][charge][thr] = kerdw23[arm][charge][thr] * kerw[arm][charge][thr]
            
            m[arm][charge][thr] = GPy.models.GPRegression(coordinates[arm][charge][thr],values[arm][charge][thr],ker[arm][charge][thr])
            
            # create model using input uncertainty:
            kerdw23uncert[arm][charge][thr] = GPy.kern.RBF(input_dim=1,variance=100,lengthscale=.05,active_dims=[0])
            kerwuncert[arm][charge][thr] = GPy.kern.RBF(input_dim=1,variance=100,lengthscale=.05,active_dims=[1])
            kerfix[arm][charge][thr] = GPy.kern.Fixed(2,GPy.util.linalg.tdot(uncert[arm][charge][thr]))
            keruncert[arm][charge][thr] = kerdw23uncert[arm][charge][thr] * kerwuncert[arm][charge][thr] + kerfix[arm][charge][thr]
            
            m_uncert[arm][charge][thr] = GPy.models.GPRegression(coordinates[arm][charge][thr],values[arm][charge][thr],keruncert[arm][charge][thr])
            m_uncert[arm][charge][thr].Gaussian_noise.fix(1e-6)
# Out:
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise

# %%
kerdw23_scaled = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
kerw_scaled = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
ker_scaled = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]

kerdw23uncert_scaled = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
kerwuncert_scaled = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
kerfix_scaled = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
keruncert_scaled = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]

m_scaled = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
m_uncert_scaled = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]

for arm in range(2):
    for charge in range(2):
        for thr in range(3):

            # create simple model:
            kerdw23_scaled[arm][charge][thr] = GPy.kern.RBF(input_dim=1,variance=.1,lengthscale=.05,active_dims=[0])
            kerw_scaled[arm][charge][thr] = GPy.kern.RBF(input_dim=1,variance=.01,lengthscale=.05,active_dims=[1])
            ker_scaled[arm][charge][thr] = kerdw23_scaled[arm][charge][thr] * kerw_scaled[arm][charge][thr]
             
            m_scaled[arm][charge][thr] = GPy.models.GPRegression(coordinates[arm][charge][thr],scaled_values[arm][charge][thr],ker_scaled[arm][charge][thr])
            
            # create model using input uncertainty:
            kerdw23uncert_scaled[arm][charge][thr] = GPy.kern.RBF(input_dim=1,variance=.1,lengthscale=.05,active_dims=[0])
            kerwuncert_scaled[arm][charge][thr] = GPy.kern.RBF(input_dim=1,variance=.01,lengthscale=.05,active_dims=[1])
            kerfix_scaled[arm][charge][thr] = GPy.kern.Fixed(2,GPy.util.linalg.tdot(scaled_uncert[arm][charge][thr]))
            keruncert_scaled[arm][charge][thr] = kerdw23uncert_scaled[arm][charge][thr] * kerwuncert_scaled[arm][charge][thr] + kerfix_scaled[arm][charge][thr]
            
            m_uncert_scaled[arm][charge][thr] = GPy.models.GPRegression(coordinates[arm][charge][thr],scaled_values[arm][charge][thr],keruncert_scaled[arm][charge][thr])
            m_uncert_scaled[arm][charge][thr].Gaussian_noise.fix(1e-6)
# Out:
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise

# %%
kerdw23_log = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
kerw_log = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
ker_log = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]

kerdw23uncert_log = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
kerwuncert_log = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
kerfix_log = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
keruncert_log = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]

m_log = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
m_uncert_log = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]

for arm in range(2):
    for charge in range(2):
        for thr in range(3):

            # create simple model:
            kerdw23_log[arm][charge][thr] = GPy.kern.RBF(input_dim=1,variance=100,lengthscale=.05,active_dims=[0])
            kerw_log[arm][charge][thr] = GPy.kern.RBF(input_dim=1,variance=100,lengthscale=.05,active_dims=[1])
            ker_log[arm][charge][thr] = kerdw23_log[arm][charge][thr] * kerw_log[arm][charge][thr]
            
            m_log[arm][charge][thr] = GPy.models.GPRegression(coordinates[arm][charge][thr],log_values[arm][charge][thr],ker_log[arm][charge][thr])
            
            # create model using input uncertainty:
            kerdw23uncert_log[arm][charge][thr] = GPy.kern.RBF(input_dim=1,variance=100,lengthscale=.05,active_dims=[0])
            kerwuncert_log[arm][charge][thr] = GPy.kern.RBF(input_dim=1,variance=100,lengthscale=.05,active_dims=[1])
            kerfix_log[arm][charge][thr] = GPy.kern.Fixed(2,GPy.util.linalg.tdot(log_uncert[arm][charge][thr]))
            keruncert_log[arm][charge][thr] = kerdw23uncert_log[arm][charge][thr] * kerwuncert_log[arm][charge][thr] + kerfix_log[arm][charge][thr]
            
            m_uncert_log[arm][charge][thr] = GPy.models.GPRegression(coordinates[arm][charge][thr],log_values[arm][charge][thr],keruncert_log[arm][charge][thr])
            m_uncert_log[arm][charge][thr].Gaussian_noise.fix(1e-6)
# Out:
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise
# WARNING: reconstraining parameters GP_regression.Gaussian_noise

# %%
# optimize kernel parameters (i.e. - "run" the GPR)
for arm in range(2):
    for charge in range(2):
        for thr in range(3):
            print '\n\nArm%d Charge%d Threshold%.1f\n'%(arm,charge,.7+thr/10.)
            m[arm][charge][thr].optimize(max_f_eval = 1000)
            m_uncert[arm][charge][thr].optimize(max_f_eval = 1000)
            print(m[arm][charge][thr])
            print(m_uncert[arm][charge][thr])
# Out:
# Arm0 Charge0 Threshold0.7
#
#
# Name                 : GP regression
# Log-likelihood       : -2387.52007915
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value       |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |    22.8537199864  |     +ve      |         |
#   mul.rbf_1.lengthscale    |  0.0531656154374  |     +ve      |         |
#   mul.rbf_2.variance       |    22.8537199867  |     +ve      |         |
#   mul.rbf_2.lengthscale    |   0.237262956925  |     +ve      |         |
#   Gaussian_noise.variance  |    8.46767617941  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : -3004.62699445
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |       Value       |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |    10.5817463117  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.0177108555365  |     +ve      |         |
#   add.mul.rbf_2.variance     |    10.5817463156  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |  0.0181670855782  |     +ve      |         |
#   add.fixed.variance         |    58.1164200784  |     +ve      |         |
#   Gaussian_noise.variance    |            1e-06  |    fixed     |         |
#
#
# Arm0 Charge0 Threshold0.8
#
#
# Name                 : GP regression
# Log-likelihood       : -2745.04014763
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value       |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |    25.5197508799  |     +ve      |         |
#   mul.rbf_1.lengthscale    |  0.0528046157618  |     +ve      |         |
#   mul.rbf_2.variance       |     25.519750879  |     +ve      |         |
#   mul.rbf_2.lengthscale    |   0.282124424815  |     +ve      |         |
#   Gaussian_noise.variance  |      8.003363104  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : -3490.83768619
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |       Value       |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |    10.2398058907  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.0174694558232  |     +ve      |         |
#   add.mul.rbf_2.variance     |    10.2398058861  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |  0.0179545355177  |     +ve      |         |
#   add.fixed.variance         |    59.9024709376  |     +ve      |         |
#   Gaussian_noise.variance    |            1e-06  |    fixed     |         |
#
#
# Arm0 Charge0 Threshold0.9
#
#
# Name                 : GP regression
# Log-likelihood       : -3117.71164156
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value       |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |    30.6140441633  |     +ve      |         |
#   mul.rbf_1.lengthscale    |  0.0502088242729  |     +ve      |         |
#   mul.rbf_2.variance       |    30.6140441608  |     +ve      |         |
#   mul.rbf_2.lengthscale    |   0.340895105215  |     +ve      |         |
#   Gaussian_noise.variance  |    7.78585671365  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : -3977.70455704
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |       Value       |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |    10.0624849202  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.0173866088801  |     +ve      |         |
#   add.mul.rbf_2.variance     |    10.0624849177  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |  0.0178426009088  |     +ve      |         |
#   add.fixed.variance         |    64.6807037111  |     +ve      |         |
#   Gaussian_noise.variance    |            1e-06  |    fixed     |         |
#
#
# Arm0 Charge1 Threshold0.7
#
#
# Name                 : GP regression
# Log-likelihood       : -2485.49527362
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value       |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |    37.1762441202  |     +ve      |         |
#   mul.rbf_1.lengthscale    |  0.0477652502023  |     +ve      |         |
#   mul.rbf_2.variance       |    37.1762441202  |     +ve      |         |
#   mul.rbf_2.lengthscale    |   0.268194620201  |     +ve      |         |
#   Gaussian_noise.variance  |    9.81713984128  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : -3220.07923389
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |       Value       |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |    13.1551927263  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.0177509965989  |     +ve      |         |
#   add.mul.rbf_2.variance     |    13.1551927264  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |  0.0176345293903  |     +ve      |         |
#   add.fixed.variance         |   0.983028196202  |     +ve      |         |
#   Gaussian_noise.variance    |            1e-06  |    fixed     |         |
#
#
# Arm0 Charge1 Threshold0.8
#
#
# Name                 : GP regression
# Log-likelihood       : -2869.72626351
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value       |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |    34.8985406374  |     +ve      |         |
#   mul.rbf_1.lengthscale    |  0.0458209759978  |     +ve      |         |
#   mul.rbf_2.variance       |    34.8985406374  |     +ve      |         |
#   mul.rbf_2.lengthscale    |   0.265149940436  |     +ve      |         |
#   Gaussian_noise.variance  |    9.35041838968  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : -3920.27755134
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |       Value        |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |     15.5702263434  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |   0.0217834202035  |     +ve      |         |
#   add.mul.rbf_2.variance     |      15.570226343  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |  0.00389519455414  |     +ve      |         |
#   add.fixed.variance         |    0.994367627269  |     +ve      |         |
#   Gaussian_noise.variance    |             1e-06  |    fixed     |         |
#
#
# Arm0 Charge1 Threshold0.9
#
#
# Name                 : GP regression
# Log-likelihood       : -3277.73312055
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value       |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |    41.9533381445  |     +ve      |         |
#   mul.rbf_1.lengthscale    |  0.0447092565157  |     +ve      |         |
#   mul.rbf_2.variance       |    41.9533381444  |     +ve      |         |
#   mul.rbf_2.lengthscale    |   0.303298964966  |     +ve      |         |
#   Gaussian_noise.variance  |    9.37052592538  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : -4487.19185692
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |       Value       |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |    15.7111604442  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.0218352755152  |     +ve      |         |
#   add.mul.rbf_2.variance     |    15.7111604416  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |   0.002389786968  |     +ve      |         |
#   add.fixed.variance         |    1.02961258356  |     +ve      |         |
#   Gaussian_noise.variance    |            1e-06  |    fixed     |         |
#
#
# Arm1 Charge0 Threshold0.7
#
#
# Name                 : GP regression
# Log-likelihood       : -2441.56056106
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value       |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |    27.7374236285  |     +ve      |         |
#   mul.rbf_1.lengthscale    |  0.0599139361719  |     +ve      |         |
#   mul.rbf_2.variance       |    27.7374236332  |     +ve      |         |
#   mul.rbf_2.lengthscale    |   0.306411317978  |     +ve      |         |
#   Gaussian_noise.variance  |    10.0394983698  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : -3100.16446532
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |       Value       |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |    11.5724604936  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.0168124034513  |     +ve      |         |
#   add.mul.rbf_2.variance     |     11.572460332  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |  0.0186307344875  |     +ve      |         |
#   add.fixed.variance         |    720.238160658  |     +ve      |         |
#   Gaussian_noise.variance    |            1e-06  |    fixed     |         |
#
#
# Arm1 Charge0 Threshold0.8
#
#
# Name                 : GP regression
# Log-likelihood       : -2813.63134915
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |      Value       |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |   28.4712880703  |     +ve      |         |
#   mul.rbf_1.lengthscale    |  0.057710313779  |     +ve      |         |
#   mul.rbf_2.variance       |   28.4712880694  |     +ve      |         |
#   mul.rbf_2.lengthscale    |  0.325912219736  |     +ve      |         |
#   Gaussian_noise.variance  |   9.46098297844  |     +ve      |         |

# %%
# optimize kernel parameters (i.e. - "run" the GPR)
for arm in range(2):
    for charge in range(2):
        for thr in range(3):
            print '\n\nArm%d Charge%d Threshold%.1f\n'%(arm,charge,.7+thr/10.)
            m_scaled[arm][charge][thr].optimize(max_f_eval = 1000)
            m_uncert_scaled[arm][charge][thr].optimize(max_f_eval = 1000)
            print(m_scaled[arm][charge][thr])
            print(m_uncert_scaled[arm][charge][thr])
# Out:
# Arm0 Charge0 Threshold0.7
#
#
# Name                 : GP regression
# Log-likelihood       : 1326.09238007
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value        |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |    0.138743802473  |     +ve      |         |
#   mul.rbf_1.lengthscale    |    0.217021922422  |     +ve      |         |
#   mul.rbf_2.variance       |   0.0143526045218  |     +ve      |         |
#   mul.rbf_2.lengthscale    |    0.181254015112  |     +ve      |         |
#   Gaussian_noise.variance  |  0.00293290936555  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : 2064.27862041
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |       Value        |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |    0.077174403056  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |   0.0014431754322  |     +ve      |         |
#   add.mul.rbf_2.variance     |  0.00763590540551  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |  0.00160692075984  |     +ve      |         |
#   add.fixed.variance         |     1.29986224871  |     +ve      |         |
#   Gaussian_noise.variance    |             1e-06  |    fixed     |         |
#
#
# Arm0 Charge0 Threshold0.8
#
#
# Name                 : GP regression
# Log-likelihood       : 1629.86092049
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value        |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |    0.127879518621  |     +ve      |         |
#   mul.rbf_1.lengthscale    |    0.195794773909  |     +ve      |         |
#   mul.rbf_2.variance       |   0.0131188113331  |     +ve      |         |
#   mul.rbf_2.lengthscale    |    0.174987122589  |     +ve      |         |
#   Gaussian_noise.variance  |  0.00250033156207  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : 2545.68184212
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |       Value        |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |   0.0678827012096  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.00138061679094  |     +ve      |         |
#   add.mul.rbf_2.variance     |  0.00668700890069  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |  0.00165857151203  |     +ve      |         |
#   add.fixed.variance         |     1.28558698236  |     +ve      |         |
#   Gaussian_noise.variance    |             1e-06  |    fixed     |         |
#
#
# Arm0 Charge0 Threshold0.9
#
#
# Name                 : GP regression
# Log-likelihood       : 1945.27092959
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value        |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |     0.11909540893  |     +ve      |         |
#   mul.rbf_1.lengthscale    |     0.18358506553  |     +ve      |         |
#   mul.rbf_2.variance       |   0.0121170822801  |     +ve      |         |
#   mul.rbf_2.lengthscale    |    0.172053288069  |     +ve      |         |
#   Gaussian_noise.variance  |  0.00217667724056  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : 3037.4202804
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |       Value        |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |   0.0611862445909  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.00136430618027  |     +ve      |         |
#   add.mul.rbf_2.variance     |  0.00599518970622  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |  0.00165286860094  |     +ve      |         |
#   add.fixed.variance         |     1.27433489819  |     +ve      |         |
#   Gaussian_noise.variance    |             1e-06  |    fixed     |         |
#
#
# Arm0 Charge1 Threshold0.7
#
#
# Name                 : GP regression
# Log-likelihood       : 1321.25007492
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value        |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |    0.276412035987  |     +ve      |         |
#   mul.rbf_1.lengthscale    |    0.403463587394  |     +ve      |         |
#   mul.rbf_2.variance       |   0.0321313669496  |     +ve      |         |
#   mul.rbf_2.lengthscale    |    0.130900214264  |     +ve      |         |
#   Gaussian_noise.variance  |  0.00290268632832  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : 2088.21590576
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |        Value        |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |    0.0831834247591  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.000606086678224  |     +ve      |         |
#   add.mul.rbf_2.variance     |    0.0082923061297  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |    0.0150063650097  |     +ve      |         |
#   add.fixed.variance         |       1.4819873777  |     +ve      |         |
#   Gaussian_noise.variance    |              1e-06  |    fixed     |         |
#
#
# Arm0 Charge1 Threshold0.8
#
#
# Name                 : GP regression
# Log-likelihood       : 1622.38431468
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value        |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |    0.266727391691  |     +ve      |         |
#   mul.rbf_1.lengthscale    |    0.371553220366  |     +ve      |         |
#   mul.rbf_2.variance       |   0.0307382675893  |     +ve      |         |
#   mul.rbf_2.lengthscale    |    0.135904429432  |     +ve      |         |
#   Gaussian_noise.variance  |  0.00248585063306  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : 2547.55917543
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |        Value        |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |    0.0742775027075  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.000670502409822  |     +ve      |         |
#   add.mul.rbf_2.variance     |   0.00740032969135  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |    0.0147343441648  |     +ve      |         |
#   add.fixed.variance         |      1.48032346394  |     +ve      |         |
#   Gaussian_noise.variance    |              1e-06  |    fixed     |         |
#
#
# Arm0 Charge1 Threshold0.9
#
#
# Name                 : GP regression
# Log-likelihood       : 1932.80618756
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value        |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |     0.25732646386  |     +ve      |         |
#   mul.rbf_1.lengthscale    |    0.338149947323  |     +ve      |         |
#   mul.rbf_2.variance       |   0.0294643154901  |     +ve      |         |
#   mul.rbf_2.lengthscale    |    0.144024536378  |     +ve      |         |
#   Gaussian_noise.variance  |  0.00217986733247  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : 3017.79259016
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |        Value        |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |    0.0674321256424  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.000627535136323  |     +ve      |         |
#   add.mul.rbf_2.variance     |   0.00674257463741  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |    0.0145035978872  |     +ve      |         |
#   add.fixed.variance         |      1.47947797552  |     +ve      |         |
#   Gaussian_noise.variance    |              1e-06  |    fixed     |         |
#
#
# Arm1 Charge0 Threshold0.7
#
#
# Name                 : GP regression
# Log-likelihood       : 1642.48163015
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value        |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |    0.280654117402  |     +ve      |         |
#   mul.rbf_1.lengthscale    |    0.286717959632  |     +ve      |         |
#   mul.rbf_2.variance       |    0.032630134462  |     +ve      |         |
#   mul.rbf_2.lengthscale    |   0.0947741232408  |     +ve      |         |
#   Gaussian_noise.variance  |  0.00135042265352  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : 2140.77767932
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |        Value        |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |    0.0795422354602  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.000397609222099  |     +ve      |         |
#   add.mul.rbf_2.variance     |   0.00795879735791  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |    0.0154724331149  |     +ve      |         |
#   add.fixed.variance         |      2.00776590918  |     +ve      |         |
#   Gaussian_noise.variance    |              1e-06  |    fixed     |         |
#
#
# Arm1 Charge0 Threshold0.8
#
#
# Name                 : GP regression
# Log-likelihood       : 2003.56586338
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value        |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |    0.253992127681  |     +ve      |         |
#   mul.rbf_1.lengthscale    |    0.271517235548  |     +ve      |         |
#   mul.rbf_2.variance       |   0.0289869338539  |     +ve      |         |
#   mul.rbf_2.lengthscale    |   0.0990915118893  |     +ve      |         |
#   Gaussian_noise.variance  |  0.00114780795839  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : 2607.75589571
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |        Value        |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |    0.0712895929394  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.000400488750915  |     +ve      |         |
#   add.mul.rbf_2.variance     |   0.00712998981192  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |    0.0152979385418  |     +ve      |         |
#   add.fixed.variance         |      1.96248552163  |     +ve      |         |
#   Gaussian_noise.variance    |              1e-06  |    fixed     |         |
#
#
# Arm1 Charge0 Threshold0.9
#
#
# Name                 : GP regression
# Log-likelihood       : 2370.60785561
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value       |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |   0.242041396197  |     +ve      |         |
#   mul.rbf_1.lengthscale    |   0.256327105194  |     +ve      |         |
#   mul.rbf_2.variance       |   0.027294045343  |     +ve      |         |
#   mul.rbf_2.lengthscale    |   0.101560496718  |     +ve      |         |
#   Gaussian_noise.variance  |  0.0010022714336  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : 3087.4109516
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |        Value        |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |    0.0646418411879  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.000404933545554  |     +ve      |         |
#   add.mul.rbf_2.variance     |   0.00648673363321  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |    0.0150699011274  |     +ve      |         |
#   add.fixed.variance         |      1.96177581996  |     +ve      |         |
#   Gaussian_noise.variance    |              1e-06  |    fixed     |         |
#
#
# Arm1 Charge1 Threshold0.7
#
#
# Name                 : GP regression
# Log-likelihood       : 1668.25991441
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value        |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |    0.146405903401  |     +ve      |         |
#   mul.rbf_1.lengthscale    |    0.227211986081  |     +ve      |         |
#   mul.rbf_2.variance       |   0.0152520107305  |     +ve      |         |
#   mul.rbf_2.lengthscale    |   0.0506549237885  |     +ve      |         |
#   Gaussian_noise.variance  |  0.00126079274359  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : 2170.20120412
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |        Value        |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |     0.078236895037  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.000695045286777  |     +ve      |         |
#   add.mul.rbf_2.variance     |   0.00780223225696  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |    0.0158909720882  |     +ve      |         |
#   add.fixed.variance         |      1.82505895094  |     +ve      |         |
#   Gaussian_noise.variance    |              1e-06  |    fixed     |         |
#
#
# Arm1 Charge1 Threshold0.8
#
#
# Name                 : GP regression
# Log-likelihood       : 2027.90811023
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |       Value        |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |    0.136504479478  |     +ve      |         |
#   mul.rbf_1.lengthscale    |    0.219035717879  |     +ve      |         |
#   mul.rbf_2.variance       |   0.0140814260656  |     +ve      |         |
#   mul.rbf_2.lengthscale    |   0.0511999871635  |     +ve      |         |
#   Gaussian_noise.variance  |  0.00107837410998  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : 2644.82414738
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |        Value        |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |    0.0698735539999  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.000619688736265  |     +ve      |         |
#   add.mul.rbf_2.variance     |    0.0069658897005  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |    0.0157036268667  |     +ve      |         |
#   add.fixed.variance         |      1.81352298985  |     +ve      |         |
#   Gaussian_noise.variance    |              1e-06  |    fixed     |         |
#
#
# Arm1 Charge1 Threshold0.9
#
#
# Name                 : GP regression
# Log-likelihood       : 2396.59503142
# Number of Parameters : 5
# Parameters:
#   GP_regression.           |        Value        |  Constraint  |  Prior  |  Tied to
#   mul.rbf_1.variance       |     0.127308641408  |     +ve      |         |
#   mul.rbf_1.lengthscale    |     0.206398825857  |     +ve      |         |
#   mul.rbf_2.variance       |     0.013047027203  |     +ve      |         |
#   mul.rbf_2.lengthscale    |    0.0516620424464  |     +ve      |         |
#   Gaussian_noise.variance  |  0.000943683745053  |     +ve      |         |
#
# Name                 : GP regression
# Log-likelihood       : 3131.08162597
# Number of Parameters : 6
# Parameters:
#   GP_regression.             |        Value        |  Constraint  |  Prior  |  Tied to
#   add.mul.rbf_1.variance     |    0.0636212625666  |     +ve      |         |
#   add.mul.rbf_1.lengthscale  |  0.000578923245282  |     +ve      |         |
#   add.mul.rbf_2.variance     |   0.00630627286875  |     +ve      |         |
#   add.mul.rbf_2.lengthscale  |    0.0155058611295  |     +ve      |         |
#   add.fixed.variance         |      1.80855965471  |     +ve      |         |
#   Gaussian_noise.variance    |              1e-06  |    fixed     |         |

# %%
# optimize kernel parameters (i.e. - "run" the GPR)
for arm in range(2):
    for charge in range(2):
        for thr in range(3):
            print '\n\nArm%d Charge%d Threshold%.1f\n'%(arm,charge,.7+thr/10.)
            m_log[arm][charge][thr].optimize(max_f_eval = 1000)
            m_uncert_log[arm][charge][thr].optimize(max_f_eval = 1000)
            print(m_log[arm][charge][thr])
            print(m_uncert_log[arm][charge][thr])

# %% [markdown]
# #--------------------------------
# # Get GPR Results & Write to file
# #--------------------------------

# %%
# create a grid of dw23 & wness points to use
# for prediction points from our model
def get_dw23_wness_coords(dobincenter,dw23bins,dw23lower,dw23upper,wbins,wlower,wupper):
    '''
    first argument is int(bool) on whether to 
    takes integer/float input on spacing/limits for the data point grid
    outputs a 2d array that is a grid of x values for making predictions
    '''

    dw23increment = (dw23upper-dw23lower)/dw23bins
    wincrement = (wupper-wlower)/wbins

    if(dobincenter):
        dw23lower = dw23lower+dw23increment/2
        dw23upper = dw23upper+dw23increment/2
        wlower = wlower+wincrement/2
        wupper = wupper+wincrement/2
    
    dw23range = np.arange(dw23lower,dw23upper,dw23increment)
    wrange = np.arange(wlower,wupper,wincrement)

    first_time = 1
    for dw23 in dw23range:
        for w in wrange:
            if first_time:
                predict_coords = np.array([[dw23,w]])
                first_time = 0
            else:
                predict_coords = np.concatenate((predict_coords,[[dw23,w]]),axis=0)
                
    return predict_coords

predict_coords = get_dw23_wness_coords(1, 120.,-.3,.3, 200.,0.,1.)

# %%
mean = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
var = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
mean_uncert = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
var_uncert = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]

for arm in range(2):
    for charge in range(2):
        for thr in range(3):
            #extract prediced mean/variance values from model
            mean[arm][charge][thr], var[arm][charge][thr] = m[arm][charge][thr].predict(predict_coords)
            mean_uncert[arm][charge][thr], var_uncert[arm][charge][thr] = \
            m_uncert[arm][charge][thr].predict(predict_coords,kernel=kerdw23uncert[arm][charge][thr].copy()*kerwuncert[arm][charge][thr].copy())

# %%
mean_scaled = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
var_scaled = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
mean_uncert_scaled = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
var_uncert_scaled = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]

for arm in range(2):
    for charge in range(2):
        for thr in range(3):
            #extract prediced mean/variance values from model
            mean_scaled[arm][charge][thr], var_scaled[arm][charge][thr] = m_scaled[arm][charge][thr].predict(predict_coords)
            mean_uncert_scaled[arm][charge][thr], var_uncert_scaled[arm][charge][thr] = m_uncert_scaled[arm][charge][thr].predict(predict_coords)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-323e69dba0c3> in <module>()
#       9             #extract prediced mean/variance values from model
#      10             mean_scaled[arm][charge][thr], var_scaled[arm][charge][thr] = m_scaled[arm][charge][thr].predict(predict_coords)
# ---> 11             mean_uncert_scaled[arm][charge][thr], var_uncert_scaled[arm][charge][thr] = m_uncert_scaled[arm][charge][thr].predict(predict_coords)
#
# /usr/local/lib/python2.7/dist-packages/GPy-0.6.1-py2.7.egg/GPy/core/gp.pyc in predict(self, Xnew, full_cov, Y_metadata, kern)
#     216         """
#     217         #predict the latent function values
# --> 218         mu, var = self._raw_predict(Xnew, full_cov=full_cov, kern=kern)
#     219         if self.normalizer is not None:
#     220             mu, var = self.normalizer.inverse_mean(mu), self.normalizer.inverse_variance(var)
#
# /usr/local/lib/python2.7/dist-packages/GPy-0.6.1-py2.7.egg/GPy/core/gp.pyc in _raw_predict(self, _Xnew, full_cov, kern)
#     180             kern = self.kern
#     181
# --> 182         Kx = kern.K(_Xnew, self.X).T
#     183         WiKx = np.dot(self.posterior.woodbury_inv, Kx)
#     184         mu = np.dot(Kx.T, self.posterior.woodbury_vector)
#
# /usr/local/lib/python2.7/dist-packages/GPy-0.6.1-py2.7.egg/GPy/kern/_src/kernel_slice_operations.pyc in wrap(self, X, X2, *a, **kw)
#      63     def wrap(self, X, X2 = None, *a, **kw):
#      64         with _Slice_wrap(self, X, X2) as s:
# ---> 65             ret = f(self, s.X, s.X2, *a, **kw)
#      66         return ret
#      67     return wrap
#
# /usr/local/lib/python2.7/dist-packages/GPy-0.6.1-py2.7.egg/GPy/util/caching.pyc in __call__(self, *args, **kwargs)
#     180         except KeyError:
#     181             cacher = caches[self.f] = Cacher(self.f, self.limit, self.ignore_args, self.force_kwargs)
# --> 182         return cacher(*args, **kwargs)
#     183
#     184 class Cache_this(object):
#
# /usr/local/lib/python2.7/dist-packages/GPy-0.6.1-py2.7.egg/GPy/util/caching.pyc in __call__(self, *args, **kw)
#     106             #print 'WARNING: '+self.operation.__name__ + ' not cacheable!'
#     107             #print [not (isinstance(b, Observable)) for b in inputs]
# --> 108             return self.operation(*args, **kw)
#     109         # 3&4: check whether this cache_id has been cached, then has it changed?
#     110         try:
#
# /usr/local/lib/python2.7/dist-packages/GPy-0.6.1-py2.7.egg/GPy/kern/_src/add.pyc in K(self, X, X2, which_parts)
#      36             # if only one part is given
#      37             which_parts = [which_parts]
# ---> 38         return reduce(np.add, (p.K(X, X2) for p in which_parts))
#      39
#      40     @Cache_this(limit=2, force_kwargs=['which_parts'])
#
# ValueError: operands could not be broadcast together with shapes (24000,900) (900,900)

# %%
mean_log = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
var_log = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
mean_uncert_log = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]
var_uncert_log = [[[0 for x in range(3)] for x in range(2)] for x in range(2)]

for arm in range(2):
    for charge in range(2):
        for thr in range(3):
            #extract prediced mean/variance values from model
            mean_log[arm][charge][thr], var_log[arm][charge][thr] = m_log[arm][charge][thr].predict(predict_coords)
            mean_uncert_log[arm][charge][thr], var_uncert_log[arm][charge][thr] = m_uncert_log[arm][charge][thr].predict(predict_coords)

# exectue exponential function on results to un-do the log() we did before fitting
mean_log=np.exp(mean)-2
var_log=np.exp(var)

# %%
#write results to file
fout = open('predicted_dw23_wness_points_scaled.txt', 'w')
fout.write("index arm charge threshold dw23_bin_center wness_bin_center raw_value raw_uncertainty uncert_value uncert_uncertainty\n")

for arm in range(2):
    for charge in range(2):
        for thr in range(3):
            for i in range(0,len(mean9)):
                fout.write("%d %d %d %f %f %f %f %f\n"\
                           %(i,arm,charge,\
                             np.around(.7+thr/10.,1),\
                             predict_coords[i][0],\
                             predict_coords[i][1],\
                             mean[arm][charge][thr][i],\
                             var[arm][charge][thr][i],\
                             mean_uncert[arm][charge][thr][i],\
                             var_uncert[arm][charge][thr][i]))
